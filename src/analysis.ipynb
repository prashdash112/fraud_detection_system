# %%
import numpy as np 
import pandas as pd 

df = pd.read_csv('./data/creditcard.csv')
print("HEAD",df.head(10))
print("DESCRIBE",df.describe())
print("INFO",df.info())
print("ISNULL",df.isnull().sum())
print("ISNA",df.isna().sum())
print("DUPLICATED",df.duplicated().sum())
print("SHAPE",df.shape)
print("COLUMNS",df.columns)
# Out:
# HEAD    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# The classes are heavily skewed we need to solve this issue later.
print('No Frauds', round(df['Class'].value_counts()[0]/len(df) * 100,2), '% of the dataset')
print('Frauds', round(df['Class'].value_counts()[1]/len(df) * 100,2), '% of the dataset')
# Out:
# No Frauds 99.83 % of the dataset
# Frauds 0.17 % of the dataset

# %%
df2 = pd.read_csv("/Users/prashantsingh/Desktop/fraud_detection_system/src/data/creditcard_preprocessed.csv")
df2.iloc[:,:]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0      -1.996823 -0.701082 -0.041687  1.680101  0.976623 -0.247020  0.348012
# 1      -1.996823  0.608792  0.164138  0.109279  0.318998  0.042258 -0.060980
# 2      -1.996802 -0.700336 -0.811337  1.174270  0.270648 -0.366756  1.352655
# 3      -1.996802 -0.499064 -0.109972  1.187383 -0.608355 -0.008814  0.937245
# 4      -1.996781 -0.597606  0.535539  1.025470  0.287092 -0.297036  0.072873
# ...          ...       ...       ...       ...       ...       ...       ...
# 283721  1.642235 -6.102103  6.118855 -6.519873 -1.459282 -3.897079 -1.956335
# 283722  1.642257 -0.379208 -0.030938  1.347812 -0.520175  0.629193  0.795504
# 283723  1.642278  0.982354 -0.180433 -2.155033 -0.392355  1.908988  2.276699
# 283724  1.642278 -0.126465  0.324660  0.464577  0.489870 -0.275808  0.469130
# 283725  1.642362 -0.276860 -0.112709  0.465125 -0.355898 -0.010438 -0.486871
#
# ...

# %%
df3 = pd.read_csv("/Users/prashantsingh/Desktop/fraud_detection_system/src/data/creditcard_preprocessed_balanced_test.csv")
df3.iloc[:,:]
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 0     -0.705990  0.627767 -0.035995  0.180643  0.459935 -0.036283  0.280205
# 1      1.275941 -0.107325  0.717078 -0.504553 -0.364526  0.455932 -0.540971
# 2     -1.346436 -0.861773  0.853484  0.995789  1.540436  0.506870  0.798300
# 3     -0.876311  0.417583 -0.680621  0.340305  0.365519 -0.734111  0.367605
# 4      0.729091  1.028625  0.066661 -1.162853  0.418106  0.270858 -0.478062
# ...         ...       ...       ...       ...       ...       ...       ...
# 56741 -0.997180 -0.599772  0.485703  1.293676  1.171831  0.775011 -0.136915
# 56742  0.698447 -1.041675  1.347228 -1.391365 -0.734648 -0.089123 -0.019904
# 56743 -0.440157  0.603039 -0.118470  0.816577  0.616717 -0.828315 -0.236305
# 56744  0.691054  1.054989  0.085524 -1.214584  0.148022  0.510721 -0.244018
# 56745 -1.763740  0.637167  0.039580  0.587897  0.226431 -0.551065 -0.610428
#
# ...
